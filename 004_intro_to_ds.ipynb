# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-10, 10, 100)
y = np.sin(x)
plt.plot(x,y, marker="x")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import pandas as pd

# %%
data = {'Name': ["John", "David"],
        'Location': ["Warsaw", "Berlin"],
        'Age': [24, 29]}

# %%
pandas_data = pd.DataFrame(data)

# %%
display(pandas_data)
# Out:
#     Name Location  Age
# 0   John   Warsaw   24
# 1  David   Berlin   29

# %%
query = pandas_data[pandas_data.Age > 25]

# %%
display(query)
# Out:
#     Name Location  Age
# 1  David   Berlin   29
